# %% [markdown]
# # RESUMEN
#
# ![image.png](attachment:ad37460a-ab3d-40f5-9e56-78e6d6abffa7.png)

# %% [markdown]
# # Ejercicios
#
# ![image.png](attachment:7d3c226c-3386-429d-95de-2951faa42021.png)
#
# ![image.png](attachment:14e6e3a6-47af-4d10-905e-a9c194061aee.png)
