# %% [markdown]
# # RESUMEN CONCEPTUAL C13
#
# ![image.png](attachment:3b37b190-cd92-4ec3-8c7e-685a8df0f3e0.png)

# %% [markdown]
# # PRACTICA
#
# el objetivo para el
# modelo de un solo paso y el de varios pasos es la concentración de NO2 , y los
# objetivos para el modelo de múltiples salidas son la concentración de NO2 y la
# temperatura
#
# ![image.png](attachment:1a537207-ad66-424a-a67f-ec5b0703bf95.png)
#
# ![image.png](attachment:4d546f45-9fd6-45d2-946b-785e03d5b679.png)

# %% [markdown]
# # Resumen Conceptual C14
#
# ![image.png](attachment:30c86af6-0cda-43d0-a005-921668441122.png)
#
# ![image.png](attachment:3a0101b6-1a7e-460e-9ef7-986a14d0e8c3.png)
